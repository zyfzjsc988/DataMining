# %% [markdown]
# # accuracy

# %%
# polynomial transform process
def polynomial_extention(dataframe):
    poly = PolynomialFeatures(2)
    columns_name_list = list(dataframe.columns)
    
    X = dataframe.values
    new_X = poly.fit_transform(X)
    new_columns = poly.get_feature_names(columns_name_list)
    
    new_frame = pd.DataFrame(data = new_X,index = dataframe.index,columns = new_columns)
    return new_frame

# %%
#  all data matrix
import numpy as np
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
def all_lower(L1):
    return [s.lower() for s in L1]

training_label = pd.read_csv("../dataset/anonymized_dataset_for_ADM2017/training_label.csv")
training_label.columns = all_lower(training_label.columns.tolist())
training_label = training_label.drop(['schoolid','mcas','avecorrect'], axis=1)

student_information = pd.read_csv("student_information_106.csv")
# import others datasets : new feature , group by skill and group by clusters

# %% [markdown]
# ### training sets create

# %%
unpoly9 = pd.merge(student_information,training_label,how='inner')

# %% [markdown]
# # feature selection process

# %%
from sklearn import preprocessing
def standard_normalize(df):
    x = df.values #returns a numpy array
    scaler = preprocessing.StandardScaler()
    x_scaled = scaler.fit_transform(x)
    df = pd.DataFrame(x_scaled,columns = df.columns,index = df.index)
    return df

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid", context="talk")
rs = np.random.RandomState(7)
from minepy import MINE
from scipy.stats import pearsonr



# variance selector
def variance_selector(dataframe):
    variance = dataframe.var(axis=0)
    return variance
#     x = np.array(list(dataframe.columns))
#     ax = sns.barplot(x, variance, palette="Set3")
#     ax.set_ylabel("Variance")
#     plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='center')
#     plt.title('Variance comparison between nine ave- features') 
#     plt.tight_layout()
#     foo_fig = plt.gcf() # 'get current figure'   
#     foo_fig.savefig('variance_9.eps', format='eps', dpi=1000)
#     plt.show()
    
#由于MINE的设计不是函数式的，定义mic方法将其为函数式的，
# 返回一个二元组，二元组的第2项设置成固定的P值0.5
def mic(x, y):
    m = MINE()
    m.compute_score(x, y)
    return m.mic()

def information_selector(dataframe):
    v = dataframe.values
    MIC = []
    for i in range(106):
        MIC.append(mic(v[:,i],v[:,-1]))
    x = np.array(list(dataframe.columns))[:-1]
    
    ax = sns.barplot(x, MIC, palette="Set3")
    ax.set_ylabel("maximal information coefficient (MIC)")
    plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='center')
    plt.title('MIC comparison between nine ave- features') 
    plt.tight_layout()
    foo_fig = plt.gcf() # 'get current figure'
    foo_fig.savefig('MIC_9.eps', format='eps', dpi=1000)
    plt.show()
    
    return pd.DataFrame(MIC,index=x,columns=['MIC'])

# def pearsonr_selector(dataframe):
#     v = dataframe.values
#     p = []
#     for i in range(9):
#         p.append(pearsonr(v[:,i],v[:,-1])[0])
#     x = np.array(list(dataframe.columns))[:-1]
#     ax = sns.barplot(x, p, palette="Set3")
#     ax.set_ylabel("pearson coefficient")
#     plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='center')
#     plt.title('pearson coefficient comparison between nine ave- features')
#     plt.tight_layout()
#     foo_fig = plt.gcf() # 'get current figure'
#     foo_fig.savefig('pearson_9.eps', format='eps', dpi=1000)
#     plt.show()

# %%
unpoly9_MIC = information_selector(unpoly9.set_index('itest_id')).sort_values(by=['MIC'])
unpoly9_highMIC = unpoly9_MIC[unpoly9_MIC['MIC']>=0.2]

# %%
unpoly9_highMIC.index
# Out:
# Index(['average_questions_by_mon', 'frhrate_H', 'timetaken_M', 'hintrate_H',
#        'std_questions_by_day_H', 'std_questions_by_day_E', 'actioncount_M',
#        'correctrate_E', 'timetohint_H', 'frscaffoldh_H', 'averesgaming',
#        'timeover80rate', 'bottomhint', 'hint', 'hint_E', 'timetaken',
#        'avecorrect', 'correctrate', 'scaffold', 'frscaffoldh_M', 'timeover80',
#        'timeover80rate_M', 'timetaken_H', 'actioncount_H', 'scaffold_M',
#        'correctrate_H', 'wrongrate_M', 'timetohint', 'avecarelessness',
#        'hintrate_E', 'frhrate_E', 'aveknow', 'std_questions_by_mon_H',
#        'hint_M', 'hintrate_M', 'std_questions_by_mon', 'actioncount_E',
#        'averesofftask', 'timetohint_M', 'actioncount',
#        'std_questions_by_day_M', 'hintrate'],
#       dtype='object')

# %%
unpoly9 = unpoly9.set_index('itest_id')[unpoly9_highMIC.index]
# Out:
#           average_questions_by_mon  frhrate_H  timetaken_M  hintrate_H  \
# itest_id
# 9                        51.000000   0.548096    91.043011    0.084049
# 27                       12.250000   0.337037   208.571429    0.137037
# 33                       45.666667   0.497436    66.380000    0.043590
# 35                       59.714286   0.315930    56.864078    0.205007
# 37                       15.333333   0.634314   112.375000    0.295098
# 41                       40.800000   0.479679    68.300000    0.111296
# 77                       18.714286   0.364667    95.963855    0.099333
# 87                       50.000000   0.174812    63.634615    0.007519
# 114                      39.250000   0.331127   103.666667    0.199129
# 126                      32.142857   0.424032    87.136752    0.121751
# 129                      54.400000   0.440954   101.605505    0.127542
# 176                      42.600000   0.386364    67.118812    0.000000
# 190                      53.600000   0.441684    75.594059    0.022774
# 205                      41.714286   0.347344    60.895105    0.242491
# 224                      25.090909   0.256757    99.001844    0.000000
# 237                      32.250000   0.504054   137.568627    0.142342
# 240                      59.500000   0.171955    59.307018    0.121660
# 240                      59.500000   0.171955    59.307018    0.121660
# 263                      30.750000   0.248387   184.347826    0.008065
# 269                      45.333333   0.405004    67.553957    0.053299
# 282                      89.333333   0.304444    96.392157    0.116667
# 283                      75.666667   0.402239    43.240664    0.322143
# 303                      27.500000   0.465909   159.605263    0.102273
# 321                      38.500000   0.317937   123.888889    0.143143
# 334                      74.400000   0.459552    62.248447    0.000292
# 360                      55.125000   0.412191    57.176230    0.326368
# 363                      49.000000   0.509351    55.688547    0.092140
# 376                      30.000000   0.629630   102.793651    0.000000
# 7469                    6.839660  0.090302
# 7473                    2.121320  0.262578
# 7492                    5.549775  0.053153
# 7493                    8.502101  0.074957
# 7501                    6.744695  0.043043
# 7511                    8.866917  0.267486
# 7586                   11.970334  0.205743
# 7609                    5.228129  0.215959
# 7609                    5.228129  0.215959
# 7613                   13.316656  0.091820
# 7629                    0.707107  0.148016
# 7636                    7.847505  0.171854
# 7650                         NaN  0.386111
# 7676                   11.078234  0.306565
# 7679                    7.050836  0.034092
# 7680                    6.543560  0.076378
# 7703                   13.057565  0.054139
# 7704                    6.454972  0.127062
# 7717                    9.944903  0.338483
# 7723                    4.219005  0.062948
# 7737                   10.606602  0.135482
# 7737                   10.606602  0.135482
# 7769                    9.659193  0.042004
# 7769                    9.659193  0.042004
# 7775                   10.433463  0.194636
# 7782                   13.107613  0.184342
#
# [514 rows x 42 columns]

# %% [markdown]
# #### polynormial dataset

# %%
# polynormial dataset
stu_inf_poly = polynomial_extention(student_information.drop([
#                                                             'averesbored',
                                                              'itest_id',
#                                                               'averesengcon',
#                                                               'averesconf',
#                                                               'averesfrust'
        ],axis=1))
stu_inf_poly['itest_id'] = student_information['itest_id']
                                    

poly9 = pd.merge(stu_inf_poly,training_label,how='inner').set_index('itest_id')

# %%
dataframe = poly9
v = dataframe.values
MIC = []
for i in range(len(dataframe.columns)-1):
    MIC.append(mic(v[:,i],v[:,-1]))
x = np.array(list(dataframe.columns))[:-1]
df = pd.Series(MIC,index=x).sort_values(ascending=False)
# print(df)
# ax = sns.barplot( df.values, df.index, palette="Set3")
# ax.set_xlabel("maximal information coefficient (MIC)")
# plt.title('MIC comparison between polynormial features') 
# plt.tight_layout()
# foo_fig = plt.gcf() # 'get current figure'
# foo_fig.savefig('MIC_21.eps', format='eps', dpi=1000)
# plt.show()
len(df)
# Out:
# 55

# %% [markdown]
# #### added new feature

# %%
student_information_added = pd.read_csv("student_information.csv").drop(['numactions'],axis=1)
unpoly21 = pd.merge(student_information_added,training_label,how='inner').set_index('itest_id')

# %%
dataframe = unpoly21
v = dataframe.values
MIC = []
for i in range(len(dataframe.columns)-1):
    MIC.append(mic(v[:,i],v[:,-1]))
x = np.array(list(dataframe.columns))[:-1]
df = pd.Series(MIC,index=x).sort_values(ascending=False)
ax = sns.barplot( df.values, df.index, palette="Set3")
ax.set_xlabel("maximal information coefficient (MIC)")
plt.title('MIC comparison between 21 features') 
plt.tight_layout()
foo_fig = plt.gcf() # 'get current figure'
foo_fig.savefig('MIC_added_21.eps', format='eps', dpi=1000)
plt.show()

# %%
# check relationship between features
corr = unpoly9.corr().round(2)  
# print(corr)
sns.set(style="white")
sns.heatmap(corr, cmap="YlGnBu")
plt.title('Correlation between 21 features') 
plt.tight_layout()
foo_fig = plt.gcf() # 'get current figure'
foo_fig.savefig('correlation_21.eps', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# ### training models
