# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  
stu_ques = pd.read_csv("../dataset/person_and_question_relationship.csv",header=0)
question_information = pd.read_csv("../dataset/question_information.csv",header=0)

# %%
stu_que_matrix = pd.merge(stu_ques, question_information, how='left')
stu_que_matrix.columns.values
# Out:
# array(['itest_id', 'problemid', 'actioncount', 'bottomhint', 'correct',
#        'correctrate', 'dayfinishquestion', 'end_time_day',
#        'end_time_month', 'endtime', 'filedin', 'frhrate', 'frscaffoldh',
#        'hint', 'hintrate', 'monthfinishquestion', 'scaffold',
#        'timefinishquestion', 'timeover80', 'timeover80rate', 'timetaken',
#        'timetohint', 'workinschoolrate', 'wrong', 'wrongrate', 'skill'],
#       dtype=object)

# %% [markdown]
# 把学生和skill联系起来，每个skill正确率大于0.5的学生多少人，小于0.5的学生多少人
#
# 正确率大于0.5且去了stem的学生多少人，小于0.5且去了stem的学生多少人
#
# 正确率大于0.5且没去stem的学生多少人，小于0.5且没去stem的学生多少人
#
# 我们可以评估skill的难度

# %%
stu_que_matrix = pd.merge(stu_ques, question_information, how='left')
from tqdm import tqdm
train=pd.read_csv('training_label.csv',header=0)
train = train.rename(columns={'ITEST_id':'itest_id'})
train=train.set_index('itest_id')
# print(train)
# stu_que_matrix = pd.merge(stu_ques, question_information, how='left')
# stu_que_matrix=stu_que_matrix.set_index('itest_id')
# print(stu_que_matrix)
# sq=pd.merge(stu_que_matrix,train,how='left')
ls=np.ndarray.tolist(stu_que_matrix.skill.values)
ls3=[]
lls=[]
lls1=[]
lls2=[]
lls3=[]
lls4=[]
lls5=[]
ls2 = list(set(ls))
#print(ls2)
for i in tqdm(range(len(ls2))):    
    skill=stu_que_matrix[stu_que_matrix.skill==ls2[i]]
    skill_df=skill.groupby('itest_id').mean()
    #print(skill_df)
    ls1 =skill_df.index
    ls1=ls1.tolist()
    #print(ls1)
    lss1=train.index
    lss1=lss1.tolist()
    #print(len(lss1))
    isStem=train['isSTEM'].values
    isStem=isStem.tolist()
    #print(len(isStem))
    #print(ls1)
    shape=skill_df.shape
    sh=shape[0]
    ls3.append(sh)
    n=np.array(ls3)
    length=0
    length1=0
    l=0
    l1=0
    l2=0
    l3=0
    for m in ls1:
        if skill_df.loc[m,'correctrate']>0.5:
            length+=1
            #for n in range(sh):
            if m in lss1:
                index=lss1.index(m)
                if isStem[index]==1:
                    l+=1
                elif isStem[index]==0:
                    l1+=1
        else:
            length1+=1            
            #for n in range(sh):
            if m in lss1:
                index=lss1.index(m)
                if isStem[index]==1:
                    l2+=1
                elif isStem[index]==0:
                    l3+=1
    lls.append(length)
    lls1.append(length1)
    lls2.append(l)
    lls3.append(l1)
    lls4.append(l2)
    lls5.append(l3)
# print("correct rate > 0.5:")
# print(lls)
# print("correct rate < 0.5:")
# print(lls1)
# print("correct rate is stem > 0.5:")
# print(lls2)
# print("correct rate is not stem > 0.5:")
# print(lls3)
# print("correct rate is stem < 0.5:")
# print(lls4)
# print("correct rate is not stem < 0.5:")
# print(lls5)
# Out:
#   0%|                                                                                          | 0/102 [00:00<?, ?it/s]
#   1%|▊                                                                                 | 1/102 [00:00<00:29,  3.38it/s]
lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Users\surface\Anaconda2\envs\tensorflow\lib\site-packages\tqdm\_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "C:\Users\surface\Anaconda2\envs\tensorflow\lib\_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#  66%|█████████████████████████████████████████████████████▏                           | 67/102 [00:07<00:03,  9.38it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 102/102 [00:10<00:00,  9.55it/s]

# %%
df3 = pd.DataFrame({'skill':np.array(ls2),
                    'total_number' : np.array(ls3,dtype='int32'),
                    'morethan0.5' : np.array(lls,dtype='int32'),
                    'lessthan0.5':np.array(lls1,dtype='int32'),
                    'morethan0.5stem':np.array(lls2,dtype='int32'),
                    'morethan0.5notstem':np.array(lls3,dtype='int32'),
                    'lessthan0.5stem':np.array(lls4,dtype='int32'),
                    'lessthan0.5notstem':np.array(lls5,dtype='int32')})
#df3.to_csv('skill_and_student.csv')
df3=df3.set_index('skill')
#由于去了stem的人比较少，大概没去的是去了的两倍，所以乘以二算比例
df3['lessthan0.5stem']=df3['lessthan0.5stem']*2
df3['morethan0.5stem']=df3['morethan0.5stem']*2
#df3['lessratio']=(df3['lessthan0.5stem']-df3['lessthan0.5notstem'])/df3['lessthan0.5notstem']
#df3['moreratio']=(df3['morethan0.5stem']-df3['morethan0.5notstem'])/df3['morethan0.5notstem']
#df3['less-more']=(df3['lessthan0.5']-df3['morethan0.5'])/df3['total_number']
df3['less/total']=df3['lessthan0.5']/df3['total_number']
df3['train_nostem_rate']=df3['lessthan0.5notstem']/(df3['lessthan0.5notstem']+df3['morethan0.5notstem'])
df3['train_stem_rate']=df3['lessthan0.5stem']/(df3['lessthan0.5stem']+df3['morethan0.5stem'])
#df3['less0.5nostem/total']=df3['lessthan0.5']/df3['total_number']
#df3['more/total']=df3['morethan0.5']/df3['total_number']
df3
# Out:
#                                              lessthan0.5  lessthan0.5notstem  \
# skill
# measurement                                          129                  32
# combinatorics                                        613                 117
# sum-of-interior-angles-triangle                      631                 122
# n-number-sense-operations                            395                  69
# multiplication                                       280                  50
# application: isosceles triangle                      302                  62
# pythagorean-theorem                                 1020                 209
# inequalities                                         312                  65
# m-measurement                                        201                  44
# perimeter                                            542                 104
# application: multi-column addition                     0                   0
# divide-decimals                                      361                  78
# scientific-notation                                  345                  68
# equation-solving                                     790                 150
# ordering-numbers                                     208                  31
# fraction-decimals-percents                           136                  23
# area-of-circle                                       133                  26
# percents                                             399                  60
# mode                                                 127                  17
# least-common-multiple                                332                  67
# of-means-multiply                                    352                  68
# graph-shape                                          183                  34
# similar-triangles                                      0                   0
# discount                                             763                 140
# application: read points                               0                   0
# evaluating-functions                                 654                 122
# transversals                                         546                 117
# properties-of-geometric-figures                      601                 110
# interpreting-linear-equations                        733                 150
# meaning-of-pi                                        201                  36
# ...                                                  ...                 ...
# inequality-solving                                   421                  83
# application: compare points                            0                   0
# number-line                                          282                  51
# subtracting-decimals                                 192                  36
# application: order of operations                       0                   0
# equivalent-fractions-decimals-percents               553                  99
# multiplying-positive-negative-numbers                 42                   8
# area                                                1056                 196
# rate-with-distance-and-time                          172                  36
# adding-decimals                                       43                   7
# pattern-finding                                      401                  67
# properties-of-solids                                  57                   8
# subtraction                                          224                  48
# sum-of-interior-angles-more-than-3-sides             509                 109
# surface-area-and-volume                               79                  17
# application: finding percentage of a number            1                   0
# congruence                                           264                  56
# unit-conversion                                      520                 102
# symbolization-articulation                           543                  98
# fraction-multiplication                              553                 104
# comparing-fractions                                  122                  25
# inducing-functions                                   720                 125
# isosceles-triangle                                   635                 131
# reading-graph                                        461                  88
# divisibility                                          49                   9
# probability                                          649                 115
# stem-and-leaf-plot                                   120                  18
# prime-number                                         142                  33
# substitution                                         479                  98
# mean                                                 327                  61
#
#                                              lessthan0.5stem  morethan0.5  \
# skill
# measurement                                               14           32
# combinatorics                                             66          601
# sum-of-interior-angles-triangle                           64          380
# n-number-sense-operations                                 34          371
# multiplication                                            22          900
# application: isosceles triangle                           48          125
# pythagorean-theorem                                      124          346
# inequalities                                              34           59
# m-measurement                                             28           88
# perimeter                                                 54          663
# application: multi-column addition                         0            1
# divide-decimals                                           52          250
# scientific-notation                                       40          532
# equation-solving                                          64          676
# ordering-numbers                                          22          608
# fraction-decimals-percents                                20          280
# area-of-circle                                            12          157
# percents                                                  34          580
# mode                                                      10          181
# least-common-multiple                                     30          445
# of-means-multiply                                         42          392
# graph-shape                                               18          705
# similar-triangles                                          0            8
# discount                                                  76          483
# application: read points                                   0            1
# evaluating-functions                                      90          464
# transversals                                              60          311
# properties-of-geometric-figures                           60          662
# interpreting-linear-equations                             82          496
# meaning-of-pi                                             32          180
# ...                                                      ...          ...
# inequality-solving                                        46          257
# application: compare points                                0            1
# number-line                                               22          478
# subtracting-decimals                                      20          350
# application: order of operations                           0            1
# equivalent-fractions-decimals-percents                    54          805
# multiplying-positive-negative-numbers                      4          105
# area                                                     106          473
# rate-with-distance-and-time                               22          339
# adding-decimals                                            6          164
# pattern-finding                                           32         1020
# properties-of-solids                                       6          103
# subtraction                                               14          694
# sum-of-interior-angles-more-than-3-sides                  78          324
# surface-area-and-volume                                   20           73
# application: finding percentage of a number                0            0
# congruence                                                38          165
# unit-conversion                                           52          535
# symbolization-articulation                                46          673
# fraction-multiplication                                   50          615
# comparing-fractions                                        8          242
# inducing-functions                                        98          638
# isosceles-triangle                                        84          211
# reading-graph                                             48          841
# divisibility                                               6          138
# probability                                               46          815
# stem-and-leaf-plot                                        12           86
# prime-number                                              20          173
# substitution                                              56          504
# mean                                                      34          481
#
#                                              morethan0.5notstem  \
# skill
# measurement                                                   5
# combinatorics                                               139
# sum-of-interior-angles-triangle                              93
# n-number-sense-operations                                    70
# multiplication                                              195
# application: isosceles triangle                              30
# pythagorean-theorem                                          81
# inequalities                                                 12
# m-measurement                                                18
# perimeter                                                   149
# application: multi-column addition                            0
# divide-decimals                                              58
# scientific-notation                                         120
# equation-solving                                            152
# ordering-numbers                                            139
# fraction-decimals-percents                                   60
# area-of-circle                                               32
# percents                                                    138
# mode                                                         49
# least-common-multiple                                        97
# of-means-multiply                                            83
# graph-shape                                                 159
# similar-triangles                                             4
# discount                                                    119
# application: read points                                      0
# evaluating-functions                                        120
# transversals                                                 59
# properties-of-geometric-figures                             153
# interpreting-linear-equations                               112
# meaning-of-pi                                                43
# ...                                                         ...
# inequality-solving                                           66
# application: compare points                                   0
# number-line                                                 115
# subtracting-decimals                                         84
# application: order of operations                              0
# equivalent-fractions-decimals-percents                      191
# multiplying-positive-negative-numbers                        19
# area                                                        120
# rate-with-distance-and-time                                  75
# adding-decimals                                              35
# pattern-finding                                             224
# properties-of-solids                                         21
# subtraction                                                 145
# sum-of-interior-angles-more-than-3-sides                     75
# surface-area-and-volume                                      14
# application: finding percentage of a number                   0
# congruence                                                   35
# unit-conversion                                             132
# symbolization-articulation                                  162
# fraction-multiplication                                     137
# comparing-fractions                                          53
# inducing-functions                                          159
# isosceles-triangle                                           44
# reading-graph                                               197
# divisibility                                                 31
# probability                                                 197
# stem-and-leaf-plot                                           16
# prime-number                                                 43
# substitution                                                108
# mean                                                        100
#
#                                              morethan0.5stem  total_number  \
# skill
# measurement                                                8           161
# combinatorics                                            112          1214
# sum-of-interior-angles-triangle                           94          1011
# n-number-sense-operations                                 76           766
# multiplication                                           154          1180
# application: isosceles triangle                           18           427
# pythagorean-theorem                                       70          1366
# inequalities                                              10           371
# m-measurement                                             28           289
# perimeter                                                 94          1205
# application: multi-column addition                         0             1
# divide-decimals                                           50           611
# scientific-notation                                      106           877
# equation-solving                                         154          1466
# ordering-numbers                                         118           816
# fraction-decimals-percents                                42           416
# area-of-circle                                            38           290
# percents                                                 114           979
# mode                                                      42           308
# least-common-multiple                                     84           777
# of-means-multiply                                         72           744
# graph-shape                                              124           888
# similar-triangles                                          4             8
# discount                                                 122          1246
# application: read points                                   0             1
# evaluating-functions                                      94          1118
# transversals                                              52           857
# properties-of-geometric-figures                          146          1263
# interpreting-linear-equations                            108          1229
# meaning-of-pi                                             44           381
# ...                                                      ...           ...
# inequality-solving                                        58           678
# application: compare points                                0             1
# number-line                                               90           760
# subtracting-decimals                                      72           542
# application: order of operations                           0             1
# equivalent-fractions-decimals-percents                   142          1358
# multiplying-positive-negative-numbers                     22           147
# area                                                     114          1529
# rate-with-distance-and-time                               72           511
# adding-decimals                                           20           207
# pattern-finding                                          186          1421
# properties-of-solids                                      28           160
# subtraction                                              114           918
# sum-of-interior-angles-more-than-3-sides                  56           833
# surface-area-and-volume                                   12           152
# application: finding percentage of a number                0             1
# congruence                                                50           429
# unit-conversion                                          126          1055
# symbolization-articulation                               140          1216
# fraction-multiplication                                  130          1168
# comparing-fractions                                       58           364
# inducing-functions                                       106          1358
# isosceles-triangle                                        50           846
# reading-graph                                            154          1302
# divisibility                                              28           187
# probability                                              172          1464
# stem-and-leaf-plot                                        14           206
# prime-number                                              42           315
# substitution                                             112           983
# mean                                                     104           808
#
#                                              less/total  train_nostem_rate  \
# skill
# measurement                                    0.801242           0.864865
# combinatorics                                  0.504942           0.457031
# sum-of-interior-angles-triangle                0.624135           0.567442
# n-number-sense-operations                      0.515666           0.496403
# multiplication                                 0.237288           0.204082
# application: isosceles triangle                0.707260           0.673913
# pythagorean-theorem                            0.746706           0.720690
# inequalities                                   0.840970           0.844156
# m-measurement                                  0.695502           0.709677
# perimeter                                      0.449793           0.411067
# application: multi-column addition             0.000000                NaN
# divide-decimals                                0.590835           0.573529
# scientific-notation                            0.393387           0.361702
# equation-solving                               0.538881           0.496689
# ordering-numbers                               0.254902           0.182353
# fraction-decimals-percents                     0.326923           0.277108
# area-of-circle                                 0.458621           0.448276
# percents                                       0.407559           0.303030
# mode                                           0.412338           0.257576
# least-common-multiple                          0.427284           0.408537
# of-means-multiply                              0.473118           0.450331
# graph-shape                                    0.206081           0.176166
# similar-triangles                              0.000000           0.000000
# discount                                       0.612360           0.540541
# application: read points                       0.000000                NaN
# evaluating-functions                           0.584973           0.504132
# transversals                                   0.637106           0.664773
# properties-of-geometric-figures                0.475851           0.418251
# interpreting-linear-equations                  0.596420           0.572519
# meaning-of-pi                                  0.527559           0.455696
# ...                                                 ...                ...
# inequality-solving                             0.620944           0.557047
# application: compare points                    0.000000                NaN
# number-line                                    0.371053           0.307229
# subtracting-decimals                           0.354244           0.300000
# application: order of operations               0.000000                NaN
# equivalent-fractions-decimals-percents         0.407216           0.341379
# multiplying-positive-negative-numbers          0.285714           0.296296
# area                                           0.690647           0.620253
# rate-with-distance-and-time                    0.336595           0.324324
# adding-decimals                                0.207729           0.166667
# pattern-finding                                0.282196           0.230241
# properties-of-solids                           0.356250           0.275862
# subtraction                                    0.244009           0.248705
# sum-of-interior-angles-more-than-3-sides       0.611044           0.592391
# surface-area-and-volume                        0.519737           0.548387
# application: finding percentage of a number    1.000000                NaN
# congruence                                     0.615385           0.615385
# unit-conversion                                0.492891           0.435897
# symbolization-articulation                     0.446546           0.376923
# fraction-multiplication                        0.473459           0.431535
# comparing-fractions                            0.335165           0.320513
# inducing-functions                             0.530191           0.440141
# isosceles-triangle                             0.750591           0.748571
# reading-graph                                  0.354071           0.308772
# divisibility                                   0.262032           0.225000
# probability                                    0.443306           0.368590
# stem-and-leaf-plot                             0.582524           0.529412
# prime-number                                   0.450794           0.434211
# substitution                                   0.487284           0.475728
# mean                                           0.404703           0.378882
#
#                                              train_stem_rate
# skill
# measurement                                         0.636364
# combinatorics                                       0.370787
# sum-of-interior-angles-triangle                     0.405063
# n-number-sense-operations                           0.309091
# multiplication                                      0.125000
# application: isosceles triangle                     0.727273
# pythagorean-theorem                                 0.639175
# inequalities                                        0.772727
# m-measurement                                       0.500000
# perimeter                                           0.364865
# application: multi-column addition                       NaN
# divide-decimals                                     0.509804
# scientific-notation                                 0.273973
# equation-solving                                    0.293578
# ordering-numbers                                    0.157143
# fraction-decimals-percents                          0.322581
# area-of-circle                                      0.240000
# percents                                            0.229730
# mode                                                0.192308
# least-common-multiple                               0.263158
# of-means-multiply                                   0.368421
# graph-shape                                         0.126761
# similar-triangles                                   0.000000
# discount                                            0.383838
# application: read points                                 NaN
# evaluating-functions                                0.489130
# transversals                                        0.535714
# properties-of-geometric-figures                     0.291262
# interpreting-linear-equations                       0.431579
# meaning-of-pi                                       0.421053
# ...                                                      ...
# inequality-solving                                  0.442308
# application: compare points                              NaN
# number-line                                         0.196429
# subtracting-decimals                                0.217391
# application: order of operations                         NaN
# equivalent-fractions-decimals-percents              0.275510
# multiplying-positive-negative-numbers               0.153846
# area                                                0.481818
# rate-with-distance-and-time                         0.234043
# adding-decimals                                     0.230769
# pattern-finding                                     0.146789
# properties-of-solids                                0.176471
# subtraction                                         0.109375
# sum-of-interior-angles-more-than-3-sides            0.582090
# surface-area-and-volume                             0.625000
# application: finding percentage of a number              NaN
# congruence                                          0.431818
# unit-conversion                                     0.292135
# symbolization-articulation                          0.247312
# fraction-multiplication                             0.277778
# comparing-fractions                                 0.121212
# inducing-functions                                  0.480392
# isosceles-triangle                                  0.626866
# reading-graph                                       0.237624
# divisibility                                        0.176471
# probability                                         0.211009
# stem-and-leaf-plot                                  0.461538
# prime-number                                        0.322581
# substitution                                        0.333333
# mean                                                0.246377
#
# [102 rows x 10 columns]

# %% [markdown]
# 技能正确率少于0.5证明很难
#
# 根据之前计算的比率 ‘less/total’是每个技能正确率少于0.5学生人数/总学生人数
#
# 'train_nostem_rate'每个技能正确率少于0.5但是没去stem/总的没去stem的人数
#
# 'train_stem_rate'每个技能正确率少于0.5但是去了stem/总的没去stem的人数
#
# 去掉Null值，根据这三个指标分成三个簇类

# %%
from sklearn.cluster import KMeans
import json
data = df3.loc[:,['less/total','train_nostem_rate','train_stem_rate']].values 
data = df3.dropna(
    axis=0,     # 0: 对行进行操作; 1: 对列进行操作
    how='any'   # 'any': 只要存在 NaN 就 drop 掉; 'all': 必须全部是 NaN 才 drop 
    ) 
#print(data)
#假如我要构造一个聚类数为3的聚类器
estimator = KMeans(n_clusters=3)#构造聚类器
estimator.fit(data)#聚类
label_pred = estimator.labels_ #获取聚类标签
centroids = estimator.cluster_centers_ #获取聚类中心
inertia = estimator.inertia_ # 获取聚类准则的总和
# print(label_pred)
print(centroids)
# print(inertia)
list_index0=[]
list_index1=[]
list_index2=[]
index_skill=df3.index.tolist()
find0=0
index0=[i for i,v in enumerate(label_pred) if v==find0]
find1=1
index1=[i for i,v in enumerate(label_pred) if v==find1]
find2=2
index2=[i for i,v in enumerate(label_pred) if v==find2]
for i in index0:
    m=index_skill[i]
    list_index0.append(m)
for i in index1:
    m=index_skill[i]
    list_index1.append(m) 
for i in index2:
    m=index_skill[i]
    list_index2.append(m)
# print(list_index0)
# print(list_index1)
# print(list_index2)
dic = {'1':list_index0,'2':list_index1,'3':list_index2}

j = json.dumps(dic,ensure_ascii=False)
print(type(j))
with open('skill_cluster.json','w') as outfile:
    json.dump(j,outfile)
dic
# with open('skill_cluster.json','r') as outfile:
#     print(json.load(outfile))
# Out:
# [[1.23068966e+02 2.41724138e+01 1.59310345e+01 1.38517241e+02
#   3.06896552e+01 2.92413793e+01 2.61586207e+02 4.53655786e-01
#   4.34336931e-01 3.71572293e-01]
#  [3.64181818e+02 7.06969697e+01 4.10303030e+01 4.40787879e+02
#   9.91212121e+01 8.86666667e+01 8.04969697e+02 4.53775067e-01
#   4.17783586e-01 3.15247002e-01]
#  [5.80233333e+02 1.10133333e+02 5.91333333e+01 6.54233333e+02
#   1.50100000e+02 1.26666667e+02 1.23446667e+03 4.66190742e-01
#   4.21190331e-01 3.16953409e-01]]
# <class 'str'>
# {'1': ['measurement',
#   'application: isosceles triangle',
#   'inequalities',
#   'm-measurement',
#   'ordering-numbers',
#   'fraction-decimals-percents',
#   'percents',
#   'graph-shape',
#   'properties-of-geometric-figures',
#   'application: simple multiplication',
#   'rate',
#   'equation-concept',
#   'fraction-division',
#   'p-patterns-relations-algebra',
#   'g-geometry',
#   'point-plotting',
#   'graph interpretation',
#   'transformations-rotations',
#   'order-of-operations',
#   'percent-of',
#   'statistics',
#   'inequality-solving',
#   'number-line',
#   'equivalent-fractions-decimals-percents',
#   'multiplying-positive-negative-numbers',
#   'pattern-finding',
#   'surface-area-and-volume',
#   'congruence',
#   'unit-conversion'],
#  '2': ['sum-of-interior-angles-triangle',
#   'n-number-sense-operations',
#   'application: multi-column addition',
#   'divide-decimals',
#   'equation-solving',
#   'area-of-circle',
#   'mode',
#   'least-common-multiple',
#   'of-means-multiply',
#   'application: read points',
#   'interpreting-linear-equations',
#   'division',
#   'interpreting-numberline',
#   'linear-area-volume-conversion',
#   'square-root',
#   'area-concept',
#   'reduce-fraction',
#   'algebraic-manipulation',
#   'median',
#   'integers',
#   'fractions',
#   'circumference',
#   'finding-percents',
#   'making-sense-of-expressions-and-equations',
#   'addition',
#   'circle-graph',
#   'algebra symbolization',
#   'application: compare expressions',
#   'subtracting-decimals',
#   'application: order of operations',
#   'subtraction',
#   'symbolization-articulation',
#   'fraction-multiplication'],
#  '3': ['combinatorics',
#   'multiplication',
#   'pythagorean-theorem',
#   'perimeter',
#   'scientific-notation',
#   'similar-triangles',
#   'discount',
#   'evaluating-functions',
#   'transversals',
#   'meaning-of-pi',
#   'application: multi-column subtraction',
#   'application: find slope in graph',
#   'triangle-inequality',
#   'reciprocal',
#   'slope',
#   'simple-calculation',
#   'supplementary-angles',
#   'noskill',
#   'rounding',
#   'multiplying-decimals',
#   'venn-diagram',
#   'exponents',
#   'proportion',
#   'application: compare points',
#   'area',
#   'rate-with-distance-and-time',
#   'adding-decimals',
#   'properties-of-solids',
#   'sum-of-interior-angles-more-than-3-sides',
#   'application: finding percentage of a number']}

# %%
df31=df3.sort_values(['less/total'])
df31=df31['less/total']
df31.plot()
plt.show()

# %%
stu_que_matrix = pd.merge(stu_ques, question_information, how='left')
stu=stu_que_matrix.loc[0,['skill']].values.tolist()
# stu_que_matrix

# %% [markdown]
# 之前保存的三个簇类里面的技能 分别把三个簇类命名为：class1 class2 class3
#
# 把每个人回答的所有的class1簇类里面的技能的特征提取出来
#
# 把每个人回答的所有的class2簇类里面的技能的特征提取出来
#
# 。。。。
#
# 一共生成三个dataframe
#
# 然后分别groupby，再合到一起（大概每个要20分钟）

# %%
class1= dic['1']
df_class1 = stu_que_matrix[stu_que_matrix['skill'].isin(class1)]
print(len(df_class1))
class2= dic['2']
df_class2 = stu_que_matrix[stu_que_matrix['skill'].isin(class2)]
print(len(df_class2))
class3= dic['3']
df_class3 = stu_que_matrix[stu_que_matrix['skill'].isin(class3)]
print(len(df_class3))
# Out:
# 88571
# 102930
# 134416

# %% [markdown]
# ### 统计特征
# 第一类：mean
#
# 分成4种： 3个class，1个全集

# %%
mean_col_names = ['actioncount', 'bottomhint', 'correct',
       'correctrate', 'dayfinishquestion', 'filedin', 'frhrate', 'frscaffoldh',
       'hint', 'hintrate', 'monthfinishquestion', 'scaffold',
       'timeover80', 'timeover80rate', 'timetaken',
       'timetohint', 'workinschoolrate', 'wrong', 'wrongrate']
all_mean = stu_que_matrix.groupby('itest_id').mean()[mean_col_names]
c1_mean = df_class1.groupby('itest_id').mean()[mean_col_names]
c2_mean = df_class2.groupby('itest_id').mean()[mean_col_names]
c3_mean = df_class3.groupby('itest_id').mean()[mean_col_names]

# %%
# add up
student_info_matrix = pd.read_csv("../dataset/student_information.csv").set_index('itest_id')
student_info_matrix = student_info_matrix.join(all_mean,how='outer')
student_info_matrix = student_info_matrix.join(c1_mean.rename(columns = lambda x:x+'_c1'),how='outer')
student_info_matrix = student_info_matrix.join(c2_mean.rename(columns = lambda x:x+'_c2'),how='outer')
student_info_matrix = student_info_matrix.join(c3_mean.rename(columns = lambda x:x+'_c3'),how='outer')
# Out:
#            aveknow  avecarelessness  avecorrect  numactions  averesbored  \
# itest_id
# 8         0.352416         0.183276    0.483902        1056     0.208389
# 9         0.185138         0.099734    0.438492         504     0.277149
# 11        0.124832         0.090318    0.326957         575     0.262076
# 25        0.284904         0.165527    0.476718         451     0.261453
# 27        0.142031         0.069297    0.348837         129     0.330226
# 33        0.459813         0.202787    0.686391         169     0.260426
# 35        0.255164         0.158848    0.379658         993     0.222796
# 37        0.071909         0.046183    0.305785         121     0.326384
# 39        0.281693         0.152227    0.454545         418     0.274700
# 41        0.333402         0.184292    0.575251         299     0.262823
# 43        0.092026         0.032515    0.274336         113     0.266278
# 64        0.157938         0.098357    0.334038        1419     0.198394
# 65        0.106046         0.056796    0.316261         781     0.215421
# 77        0.191948         0.094195    0.413249         317     0.261455
# 83        0.074637         0.057139    0.259080         413     0.301128
# 86        0.175650         0.084595    0.408918        1054     0.250262
# 87        0.519111         0.198342    0.769565         230     0.227044
# 94        0.202292         0.121512    0.527273          55     0.303381
# 101       0.195441         0.117634    0.403553         394     0.252399
# 114       0.142242         0.085296    0.396552         348     0.267312
# 118       0.120320         0.079520    0.319461        1706     0.250864
# 124       0.108133         0.082321    0.322684         313     0.268996
# 125       0.058089         0.050379    0.319838         247     0.288641
# 126       0.250838         0.111159    0.500000         406     0.273188
# 129       0.214835         0.112077    0.444656         524     0.254312
# 131       0.248389         0.142274    0.544379         169     0.290521
# 132       0.249502         0.138376    0.500000         450     0.269245
# 134       0.183801         0.113211    0.323420         269     0.267901
# 154       0.146524         0.084286    0.344828         116     0.322649
# 156       0.271432         0.183643    0.384766         512     0.255130
# ...            ...              ...         ...         ...          ...
# 7660      0.286694         0.132463    0.547445         411     0.276640
# 7662      0.369256         0.191691    0.555249         362     0.267291
# 7663      0.135675         0.041592    0.419643         112     0.333053
# 7666      0.138828         0.084808    0.311485        1724     0.193851
# 7676      0.122347         0.079495    0.301386        1659     0.199762
# 7679      0.561024         0.280646    0.722433         263     0.273139
# 7680      0.251263         0.140633    0.490291         412     0.267071
# 7681      0.081915         0.047308    0.270239        1754     0.181203
# 7730                 1.000000  0.847328      0.316518
# 7731                 1.000000  0.364865      0.179955
# 7736                 1.000000  0.542857      0.249320
# 7737                 1.000000  0.392857      0.222817
# 7744                 1.000000  0.657658      0.220129
# 7745                 1.000000  0.655556      0.285031
# 7750                 0.998711  1.134021      0.325538
# 7753                 1.000000  0.860215      0.220406
# 7756                 1.000000  0.370370      0.216402
# 7769                 1.000000  0.565789      0.283553
# 7772                 1.000000  0.500000      0.168095
# 7775                 0.832772  1.070707      0.407007
# 7778                 0.892308  0.800000      0.324359
# 7782                 1.000000  0.811321      0.290041
# 7783                 1.000000  0.512821      0.232067
#
# [1709 rows x 86 columns]

# %% [markdown]
# 第二类：时间统计
#
# 对做题天数（月数），每天（月）平均做题个数和方差进行统计

# %%
def create_date_info_dataframe(dataframe):
    group_by_day = dataframe.groupby(['itest_id','dayfinishquestion'])
    group_by_day1 = group_by_day.count()
    average_questions_by_day  = group_by_day1.groupby(['itest_id']).mean()['problemid']
    std_questions_by_day = group_by_day1.groupby(['itest_id']).std()['problemid']
    counts_day_answer = group_by_day1.groupby(['itest_id']).count()['problemid']

    group_by_mon = dataframe.groupby(['itest_id','monthfinishquestion'])
    group_by_mon1 = group_by_mon.count()
    average_questions_by_mon = group_by_mon1.groupby(['itest_id']).mean()['problemid']
    std_questions_by_mon = group_by_mon1.groupby(['itest_id']).std()['problemid']
    counts_mon_answer = group_by_mon1.groupby(['itest_id']).count()['problemid']
    
    data = {'average_questions_by_day':average_questions_by_day,'std_questions_by_day':std_questions_by_day,
           'counts_day_answer':counts_day_answer,'average_questions_by_mon':average_questions_by_mon,
           'std_questions_by_mon':std_questions_by_mon,'counts_mon_answer':counts_mon_answer}
    new_frame = pd.DataFrame(data)
    
    return new_frame

# %%
# all
all_date = create_date_info_dataframe(stu_que_matrix)
c1_date = create_date_info_dataframe(df_class1)
c2_date = create_date_info_dataframe(df_class2)
c3_date = create_date_info_dataframe(df_class3)
# add up
student_info_matrix = student_info_matrix.join(all_date,how='outer')
student_info_matrix = student_info_matrix.join(c1_date.rename(columns = lambda x:x+'_c1'),how='outer')
student_info_matrix = student_info_matrix.join(c2_date.rename(columns = lambda x:x+'_c2'),how='outer')
student_info_matrix = student_info_matrix.join(c3_date.rename(columns = lambda x:x+'_c3'),how='outer')

# %% [markdown]
# 第三类，仅与题目相关
#
# 比如，题目超过80秒但是还是答错的

# %%
def over80_but_fair(dataframe):
    dataframe['timetaken_over80'] = (dataframe['timetaken']>80).astype(int)
    dataframe['wrong_over80'] = ((dataframe['timetaken_over80'] > 0) & (dataframe['correctrate'] == 0)).astype(int)
    group1 = dataframe.groupby('itest_id')
    wrong_and_over80 = group1.sum()['wrong_over80'] / group1.count()['problemid']
    return wrong_and_over80

# %%
student_info_matrix['wrong_and_over80'] = over80_but_fair(stu_que_matrix)
student_info_matrix['wrong_and_over80_c1'] = over80_but_fair(df_class1)
student_info_matrix['wrong_and_over80_c2'] = over80_but_fair(df_class2)
student_info_matrix['wrong_and_over80_c3'] = over80_but_fair(df_class3)
# Out:
# C:\Users\surface\Anaconda2\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\surface\Anaconda2\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
student_info_matrix.to_csv("student_information_114.csv")
