# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  
stu_ques = pd.read_csv("../dataset/person_and_question_relationship.csv",header=0)
question_information = pd.read_csv("../dataset/question_information.csv",header=0)

# %%
stu_que_matrix = pd.merge(stu_ques, question_information, how='left')
stu_que_matrix.columns.values
# Out:
# array(['itest_id', 'problemid', 'actioncount', 'bottomhint', 'correct',
#        'correctrate', 'dayfinishquestion', 'end_time_day',
#        'end_time_month', 'endtime', 'filedin', 'frhrate', 'frscaffoldh',
#        'hint', 'hintrate', 'monthfinishquestion', 'scaffold',
#        'timefinishquestion', 'timeover80', 'timeover80rate', 'timetaken',
#        'timetohint', 'workinschoolrate', 'wrong', 'wrongrate', 'skill'],
#       dtype=object)

# %% [markdown]
# 把学生和skill联系起来，每个skill正确率大于0.5的学生多少人，小于0.5的学生多少人
#
# 正确率大于0.5且去了stem的学生多少人，小于0.5且去了stem的学生多少人
#
# 正确率大于0.5且没去stem的学生多少人，小于0.5且没去stem的学生多少人
#
# 我们可以评估skill的难度

# %%
stu_que_matrix = pd.merge(stu_ques, question_information, how='left')
from tqdm import tqdm
train=pd.read_csv('training_label.csv',header=0)
train = train.rename(columns={'ITEST_id':'itest_id'})
train=train.set_index('itest_id')
# print(train)
# stu_que_matrix = pd.merge(stu_ques, question_information, how='left')
# stu_que_matrix=stu_que_matrix.set_index('itest_id')
# print(stu_que_matrix)
# sq=pd.merge(stu_que_matrix,train,how='left')
ls=np.ndarray.tolist(stu_que_matrix.skill.values)
ls3=[]
lls=[]
lls1=[]
lls2=[]
lls3=[]
lls4=[]
lls5=[]
ls2 = list(set(ls))
#print(ls2)
for i in tqdm(range(len(ls2))):    
    skill=stu_que_matrix[stu_que_matrix.skill==ls2[i]]
    skill_df=skill.groupby('itest_id').mean()
    #print(skill_df)
    ls1 =skill_df.index
    ls1=ls1.tolist()
    #print(ls1)
    lss1=train.index
    lss1=lss1.tolist()
    #print(len(lss1))
    isStem=train['isSTEM'].values
    isStem=isStem.tolist()
    #print(len(isStem))
    #print(ls1)
    shape=skill_df.shape
    sh=shape[0]
    ls3.append(sh)
    n=np.array(ls3)
    length=0
    length1=0
    l=0
    l1=0
    l2=0
    l3=0
    for m in ls1:
        if skill_df.loc[m,'correctrate']>0.5:
            length+=1
            #for n in range(sh):
            if m in lss1:
                index=lss1.index(m)
                if isStem[index]==1:
                    l+=1
                elif isStem[index]==0:
                    l1+=1
        else:
            length1+=1            
            #for n in range(sh):
            if m in lss1:
                index=lss1.index(m)
                if isStem[index]==1:
                    l2+=1
                elif isStem[index]==0:
                    l3+=1
    lls.append(length)
    lls1.append(length1)
    lls2.append(l)
    lls3.append(l1)
    lls4.append(l2)
    lls5.append(l3)
# print("correct rate > 0.5:")
# print(lls)
# print("correct rate < 0.5:")
# print(lls1)
# print("correct rate is stem > 0.5:")
# print(lls2)
# print("correct rate is not stem > 0.5:")
# print(lls3)
# print("correct rate is stem < 0.5:")
# print(lls4)
# print("correct rate is not stem < 0.5:")
# print(lls5)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 102/102 [00:08<00:00, 12.66it/s]

# %%
df3 = pd.DataFrame({'skill':np.array(ls2),
                    'total_number' : np.array(ls3,dtype='int32'),
                    'morethan0.5' : np.array(lls,dtype='int32'),
                    'lessthan0.5':np.array(lls1,dtype='int32'),
                    'morethan0.5stem':np.array(lls2,dtype='int32'),
                    'morethan0.5notstem':np.array(lls3,dtype='int32'),
                    'lessthan0.5stem':np.array(lls4,dtype='int32'),
                    'lessthan0.5notstem':np.array(lls5,dtype='int32')})
#df3.to_csv('skill_and_student.csv')
df3=df3.set_index('skill')
#由于去了stem的人比较少，大概没去的是去了的两倍，所以乘以二算比例
df3['lessthan0.5stem']=df3['lessthan0.5stem']*2
df3['morethan0.5stem']=df3['morethan0.5stem']*2
#df3['lessratio']=(df3['lessthan0.5stem']-df3['lessthan0.5notstem'])/df3['lessthan0.5notstem']
#df3['moreratio']=(df3['morethan0.5stem']-df3['morethan0.5notstem'])/df3['morethan0.5notstem']
#df3['less-more']=(df3['lessthan0.5']-df3['morethan0.5'])/df3['total_number']
df3['less/total']=df3['lessthan0.5']/df3['total_number']
df3['train_nostem_rate']=df3['lessthan0.5notstem']/(df3['lessthan0.5notstem']+df3['morethan0.5notstem'])
df3['train_stem_rate']=df3['lessthan0.5stem']/(df3['lessthan0.5stem']+df3['morethan0.5stem'])
#df3['less0.5nostem/total']=df3['lessthan0.5']/df3['total_number']
#df3['more/total']=df3['morethan0.5']/df3['total_number']
df3
# Out:
#                                        lessthan0.5  lessthan0.5notstem  \
# skill
# interpreting-linear-equations                  733                 150
# venn-diagram                                   675                 140
# similar-triangles                                0                   0
# percent-of                                     868                 158
# application: multi-column subtraction            0                   0
# rate-with-distance-and-time                    172                  36
# g-geometry                                      14                   7
# application: find slope in graph                 0                   0
# surface-area-and-volume                         79                  17
# rate                                           342                  64
# properties-of-solids                            57                   8
# circumference                                   63                  14
# integers                                       104                  20
# percents                                       399                  60
# application: multi-column addition               0                   0
# graph-shape                                    183                  34
# area                                          1056                 196
# divisibility                                    49                   9
# scientific-notation                            345                  68
# number-line                                    282                  51
# mode                                           127                  17
# unit-conversion                                520                 102
# addition                                       129                  15
# prime-number                                   142                  33
# of-means-multiply                              352                  68
# multiplication                                 280                  50
# inducing-functions                             720                 125
# finding-percents                               378                  66
# supplementary-angles                           698                 139
# noskill                                        302                  56
# ...                                            ...                 ...
# multiplying-positive-negative-numbers           42                   8
# inequalities                                   312                  65
# sum-of-interior-angles-triangle                631                 122
# subtraction                                    224                  48
# statistics                                      93                  15
# perimeter                                      542                 104
# application: isosceles triangle                302                  62
# fractions                                      478                 103
# application: compare points                      0                   0
# mean                                           327                  61
# area-of-circle                                 133                  26
# reading-graph                                  461                  88
# order-of-operations                            463                  95
# probability                                    649                 115
# fraction-decimals-percents                     136                  23
# fraction-division                              442                  78
# simple-calculation                              29                   7
# multiplying-decimals                           448                  86
# median                                         339                  58
# substitution                                   479                  98
# fraction-multiplication                        553                 104
# subtracting-decimals                           192                  36
# application: compare expressions                 0                   0
# application: order of operations                 0                   0
# adding-decimals                                 43                   7
# n-number-sense-operations                      395                  69
# congruence                                     264                  56
# application: read points                         0                   0
# meaning-of-pi                                  201                  36
# triangle-inequality                            360                  70
#
#                                        lessthan0.5stem  morethan0.5  \
# skill
# interpreting-linear-equations                       82          496
# venn-diagram                                        70          427
# similar-triangles                                    0            8
# percent-of                                         102          431
# application: multi-column subtraction                0            1
# rate-with-distance-and-time                         22          339
# g-geometry                                           2           18
# application: find slope in graph                     0            1
# surface-area-and-volume                             20           73
# rate                                                48          324
# properties-of-solids                                 6          103
# circumference                                       12           22
# integers                                            18          380
# percents                                            34          580
# application: multi-column addition                   0            1
# graph-shape                                         18          705
# area                                               106          473
# divisibility                                         6          138
# scientific-notation                                 40          532
# number-line                                         22          478
# mode                                                10          181
# unit-conversion                                     52          535
# addition                                            10          732
# prime-number                                        20          173
# of-means-multiply                                   42          392
# multiplication                                      22          900
# inducing-functions                                  98          638
# finding-percents                                    44          628
# supplementary-angles                                60          439
# noskill                                             26          728
# ...                                                ...          ...
# multiplying-positive-negative-numbers                4          105
# inequalities                                        34           59
# sum-of-interior-angles-triangle                     64          380
# subtraction                                         14          694
# statistics                                          20          194
# perimeter                                           54          663
# application: isosceles triangle                     48          125
# fractions                                           72          368
# application: compare points                          0            1
# mean                                                34          481
# area-of-circle                                      12          157
# reading-graph                                       48          841
# order-of-operations                                 46          647
# probability                                         46          815
# fraction-decimals-percents                          20          280
# fraction-division                                   50          437
# simple-calculation                                   2          203
# multiplying-decimals                                42          797
# median                                              34          476
# substitution                                        56          504
# fraction-multiplication                             50          615
# subtracting-decimals                                20          350
# application: compare expressions                     0            1
# application: order of operations                     0            1
# adding-decimals                                      6          164
# n-number-sense-operations                           34          371
# congruence                                          38          165
# application: read points                             0            1
# meaning-of-pi                                       32          180
# triangle-inequality                                 48          478
#
#                                        morethan0.5notstem  morethan0.5stem  \
# skill
# interpreting-linear-equations                         112              108
# venn-diagram                                           98              104
# similar-triangles                                       4                4
# percent-of                                            105               88
# application: multi-column subtraction                   0                0
# rate-with-distance-and-time                            75               72
# g-geometry                                              3                0
# application: find slope in graph                        0                0
# surface-area-and-volume                                14               12
# rate                                                   85               84
# properties-of-solids                                   21               28
# circumference                                           8               10
# integers                                               91               76
# percents                                              138              114
# application: multi-column addition                      0                0
# graph-shape                                           159              124
# area                                                  120              114
# divisibility                                           31               28
# scientific-notation                                   120              106
# number-line                                           115               90
# mode                                                   49               42
# unit-conversion                                       132              126
# addition                                              158              120
# prime-number                                           43               42
# of-means-multiply                                      83               72
# multiplication                                        195              154
# inducing-functions                                    159              106
# finding-percents                                      150              120
# supplementary-angles                                   90               90
# noskill                                               151              122
# ...                                                   ...              ...
# multiplying-positive-negative-numbers                  19               22
# inequalities                                           12               10
# sum-of-interior-angles-triangle                        93               94
# subtraction                                           145              114
# statistics                                             47               42
# perimeter                                             149               94
# application: isosceles triangle                        30               18
# fractions                                              84               70
# application: compare points                             0                0
# mean                                                  100              104
# area-of-circle                                         32               38
# reading-graph                                         197              154
# order-of-operations                                   139              114
# probability                                           197              172
# fraction-decimals-percents                             60               42
# fraction-division                                     104               86
# simple-calculation                                     37               32
# multiplying-decimals                                  179              148
# median                                                116              108
# substitution                                          108              112
# fraction-multiplication                               137              130
# subtracting-decimals                                   84               72
# application: compare expressions                        0                0
# application: order of operations                        0                0
# adding-decimals                                        35               20
# n-number-sense-operations                              70               76
# congruence                                             35               50
# application: read points                                0                0
# meaning-of-pi                                          43               44
# triangle-inequality                                    98               96
#
#                                        total_number  less/total  \
# skill
# interpreting-linear-equations                  1229    0.596420
# venn-diagram                                   1102    0.612523
# similar-triangles                                 8    0.000000
# percent-of                                     1299    0.668206
# application: multi-column subtraction             1    0.000000
# rate-with-distance-and-time                     511    0.336595
# g-geometry                                       32    0.437500
# application: find slope in graph                  1    0.000000
# surface-area-and-volume                         152    0.519737
# rate                                            666    0.513514
# properties-of-solids                            160    0.356250
# circumference                                    85    0.741176
# integers                                        484    0.214876
# percents                                        979    0.407559
# application: multi-column addition                1    0.000000
# graph-shape                                     888    0.206081
# area                                           1529    0.690647
# divisibility                                    187    0.262032
# scientific-notation                             877    0.393387
# number-line                                     760    0.371053
# mode                                            308    0.412338
# unit-conversion                                1055    0.492891
# addition                                        861    0.149826
# prime-number                                    315    0.450794
# of-means-multiply                               744    0.473118
# multiplication                                 1180    0.237288
# inducing-functions                             1358    0.530191
# finding-percents                               1006    0.375746
# supplementary-angles                           1137    0.613896
# noskill                                        1030    0.293204
# ...                                             ...         ...
# multiplying-positive-negative-numbers           147    0.285714
# inequalities                                    371    0.840970
# sum-of-interior-angles-triangle                1011    0.624135
# subtraction                                     918    0.244009
# statistics                                      287    0.324042
# perimeter                                      1205    0.449793
# application: isosceles triangle                 427    0.707260
# fractions                                       846    0.565012
# application: compare points                       1    0.000000
# mean                                            808    0.404703
# area-of-circle                                  290    0.458621
# reading-graph                                  1302    0.354071
# order-of-operations                            1110    0.417117
# probability                                    1464    0.443306
# fraction-decimals-percents                      416    0.326923
# fraction-division                               879    0.502844
# simple-calculation                              232    0.125000
# multiplying-decimals                           1245    0.359839
# median                                          815    0.415951
# substitution                                    983    0.487284
# fraction-multiplication                        1168    0.473459
# subtracting-decimals                            542    0.354244
# application: compare expressions                  1    0.000000
# application: order of operations                  1    0.000000
# adding-decimals                                 207    0.207729
# n-number-sense-operations                       766    0.515666
# congruence                                      429    0.615385
# application: read points                          1    0.000000
# meaning-of-pi                                   381    0.527559
# triangle-inequality                             838    0.429594
#
#                                        train_nostem_rate  train_stem_rate
# skill
# interpreting-linear-equations                   0.572519         0.431579
# venn-diagram                                    0.588235         0.402299
# similar-triangles                               0.000000         0.000000
# percent-of                                      0.600760         0.536842
# application: multi-column subtraction                NaN              NaN
# rate-with-distance-and-time                     0.324324         0.234043
# g-geometry                                      0.700000         1.000000
# application: find slope in graph                     NaN              NaN
# surface-area-and-volume                         0.548387         0.625000
# rate                                            0.429530         0.363636
# properties-of-solids                            0.275862         0.176471
# circumference                                   0.636364         0.545455
# integers                                        0.180180         0.191489
# percents                                        0.303030         0.229730
# application: multi-column addition                   NaN              NaN
# graph-shape                                     0.176166         0.126761
# area                                            0.620253         0.481818
# divisibility                                    0.225000         0.176471
# scientific-notation                             0.361702         0.273973
# number-line                                     0.307229         0.196429
# mode                                            0.257576         0.192308
# unit-conversion                                 0.435897         0.292135
# addition                                        0.086705         0.076923
# prime-number                                    0.434211         0.322581
# of-means-multiply                               0.450331         0.368421
# multiplication                                  0.204082         0.125000
# inducing-functions                              0.440141         0.480392
# finding-percents                                0.305556         0.268293
# supplementary-angles                            0.606987         0.400000
# noskill                                         0.270531         0.175676
# ...                                                  ...              ...
# multiplying-positive-negative-numbers           0.296296         0.153846
# inequalities                                    0.844156         0.772727
# sum-of-interior-angles-triangle                 0.567442         0.405063
# subtraction                                     0.248705         0.109375
# statistics                                      0.241935         0.322581
# perimeter                                       0.411067         0.364865
# application: isosceles triangle                 0.673913         0.727273
# fractions                                       0.550802         0.507042
# application: compare points                          NaN              NaN
# mean                                            0.378882         0.246377
# area-of-circle                                  0.448276         0.240000
# reading-graph                                   0.308772         0.237624
# order-of-operations                             0.405983         0.287500
# probability                                     0.368590         0.211009
# fraction-decimals-percents                      0.277108         0.322581
# fraction-division                               0.428571         0.367647
# simple-calculation                              0.159091         0.058824
# multiplying-decimals                            0.324528         0.221053
# median                                          0.333333         0.239437
# substitution                                    0.475728         0.333333
# fraction-multiplication                         0.431535         0.277778
# subtracting-decimals                            0.300000         0.217391
# application: compare expressions                     NaN              NaN
# application: order of operations                     NaN              NaN
# adding-decimals                                 0.166667         0.230769
# n-number-sense-operations                       0.496403         0.309091
# congruence                                      0.615385         0.431818
# application: read points                             NaN              NaN
# meaning-of-pi                                   0.455696         0.421053
# triangle-inequality                             0.416667         0.333333
#
# [102 rows x 10 columns]

# %% [markdown]
# 技能正确率少于0.5证明很难
#
# 根据之前计算的比率 ‘less/total’是每个技能正确率少于0.5学生人数/总学生人数
#
# 'train_nostem_rate'每个技能正确率少于0.5但是没去stem/总的没去stem的人数
#
# 'train_stem_rate'每个技能正确率少于0.5但是去了stem/总的没去stem的人数
#
# 去掉Null值，根据这三个指标分成三个簇类

# %%
from sklearn.cluster import KMeans
import json
df3 = df3.loc[:,['less/total','train_nostem_rate','train_stem_rate']]
data = df3.dropna(
    axis=0,     # 0: 对行进行操作; 1: 对列进行操作
    how='any'   # 'any': 只要存在 NaN 就 drop 掉; 'all': 必须全部是 NaN 才 drop 
    ).values 
#print(data)
#假如我要构造一个聚类数为3的聚类器
estimator = KMeans(n_clusters=3)#构造聚类器
estimator.fit(data)#聚类
label_pred = estimator.labels_ #获取聚类标签
centroids = estimator.cluster_centers_ #获取聚类中心
inertia = estimator.inertia_ # 获取聚类准则的总和
# print(label_pred)
print(centroids)
# print(inertia)
list_index0=[]
list_index1=[]
list_index2=[]
index_skill=df3.index.tolist()
find0=0
index0=[i for i,v in enumerate(label_pred) if v==find0]
find1=1
index1=[i for i,v in enumerate(label_pred) if v==find1]
find2=2
index2=[i for i,v in enumerate(label_pred) if v==find2]
for i in index0:
    m=index_skill[i]
    list_index0.append(m)
for i in index1:
    m=index_skill[i]
    list_index1.append(m) 
for i in index2:
    m=index_skill[i]
    list_index2.append(m)
# print(list_index0)
# print(list_index1)
# print(list_index2)
dic = {'1':list_index0,'2':list_index1,'3':list_index2}

j = json.dumps(dic,ensure_ascii=False)
print(type(j))
with open('skill_cluster.json','w') as outfile:
    json.dump(j,outfile)
dic
# with open('skill_cluster.json','r') as outfile:
#     print(json.load(outfile))
# Out:
# [[0.43338837 0.38563246 0.27639605]
#  [0.63636177 0.62382776 0.54169649]
#  [0.23107495 0.19854853 0.1411294 ]]
# <class 'str'>
# {'1': ['application: multi-column subtraction',
#   'application: find slope in graph',
#   'circumference',
#   'graph-shape',
#   'area',
#   'divisibility',
#   'scientific-notation',
#   'mode',
#   'unit-conversion',
#   'of-means-multiply',
#   'supplementary-angles',
#   'area-concept',
#   'application: simple multiplication',
#   'm-measurement',
#   'interpreting-numberline',
#   'least-common-multiple',
#   'graph interpretation',
#   'rounding',
#   'pattern-finding',
#   'equation-concept',
#   'divide-decimals',
#   'ordering-numbers',
#   'linear-area-volume-conversion',
#   'isosceles-triangle',
#   'exponents',
#   'transversals',
#   'properties-of-geometric-figures',
#   'measurement',
#   'square-root',
#   'sum-of-interior-angles-more-than-3-sides',
#   'sum-of-interior-angles-triangle',
#   'subtraction',
#   'statistics',
#   'perimeter',
#   'application: isosceles triangle',
#   'fractions',
#   'application: compare points',
#   'area-of-circle',
#   'reading-graph',
#   'order-of-operations',
#   'probability',
#   'fraction-decimals-percents',
#   'simple-calculation',
#   'median',
#   'substitution'],
#  '2': ['interpreting-linear-equations',
#   'venn-diagram',
#   'percent-of',
#   'rate-with-distance-and-time',
#   'g-geometry',
#   'rate',
#   'percents',
#   'prime-number',
#   'multiplication',
#   'finding-percents',
#   'proportion',
#   'comparing-fractions',
#   'pythagorean-theorem',
#   'combinatorics',
#   'algebra symbolization',
#   'reciprocal',
#   'making-sense-of-expressions-and-equations',
#   'algebraic-manipulation',
#   'stem-and-leaf-plot',
#   'inequality-solving',
#   'point-plotting',
#   'division',
#   'circle-graph',
#   'equivalent-fractions-decimals-percents',
#   'symbolization-articulation',
#   'discount',
#   'multiplying-positive-negative-numbers',
#   'inequalities',
#   'multiplying-decimals'],
#  '3': ['similar-triangles',
#   'surface-area-and-volume',
#   'properties-of-solids',
#   'integers',
#   'application: multi-column addition',
#   'number-line',
#   'addition',
#   'inducing-functions',
#   'noskill',
#   'evaluating-functions',
#   'transformations-rotations',
#   'p-patterns-relations-algebra',
#   'equation-solving',
#   'reduce-fraction',
#   'slope',
#   'application: finding percentage of a number',
#   'mean',
#   'fraction-division']}

# %%
df31=df3.sort_values(['less/total'])
df31=df31['less/total']
df31.plot()
plt.show()

# %%
stu_que_matrix = pd.merge(stu_ques, question_information, how='left')
stu=stu_que_matrix.loc[0,['skill']].values.tolist()
# stu_que_matrix

# %% [markdown]
# 之前保存的三个簇类里面的技能 分别把三个簇类命名为：class1 class2 class3
#
# 把每个人回答的所有的class1簇类里面的技能的特征提取出来
#
# 把每个人回答的所有的class2簇类里面的技能的特征提取出来
#
# 。。。。
#
# 一共生成三个dataframe
#
# 然后分别groupby，再合到一起（大概每个要20分钟）

# %%
class1= dic['1']
df_class1 = stu_que_matrix[stu_que_matrix['skill'].isin(class1)]
print(len(df_class1))
class2= dic['2']
df_class2 = stu_que_matrix[stu_que_matrix['skill'].isin(class2)]
print(len(df_class2))
class3= dic['3']
df_class3 = stu_que_matrix[stu_que_matrix['skill'].isin(class3)]
print(len(df_class3))
# Out:
# 172575
# 118850
# 90757

# %% [markdown]
# ### 统计特征
# 第一类：mean
#
# 分成4种： 3个class，1个全集

# %%
mean_col_names = ['actioncount', 'bottomhint', 'correct',
       'correctrate', 'filedin', 'frhrate', 'frscaffoldh',
       'hint', 'hintrate', 'scaffold',
       'timeover80', 'timeover80rate', 'timetaken',
       'timetohint', 'workinschoolrate', 'wrong', 'wrongrate']
all_mean = stu_que_matrix.groupby('itest_id').mean()[mean_col_names]
c1_mean = df_class1.groupby('itest_id').mean()[mean_col_names]
c2_mean = df_class2.groupby('itest_id').mean()[mean_col_names]
c3_mean = df_class3.groupby('itest_id').mean()[mean_col_names]

# %%
# add up
student_info_matrix = pd.read_csv("../dataset/student_information.csv").set_index('itest_id')
student_info_matrix = student_info_matrix.join(all_mean,how='outer')
student_info_matrix = student_info_matrix.join(c1_mean.rename(columns = lambda x:x+'_M'),how='outer')
student_info_matrix = student_info_matrix.join(c2_mean.rename(columns = lambda x:x+'_H'),how='outer')
student_info_matrix = student_info_matrix.join(c3_mean.rename(columns = lambda x:x+'_E'),how='outer')

# %% [markdown]
# 第二类：时间统计
#
# 对做题天数（月数），每天（月）平均做题个数和方差进行统计

# %%
def create_date_info_dataframe(dataframe):
    group_by_day = dataframe.groupby(['itest_id','dayfinishquestion'])
    group_by_day1 = group_by_day.count()
    average_questions_by_day  = group_by_day1.groupby(['itest_id']).mean()['problemid']
    std_questions_by_day = group_by_day1.groupby(['itest_id']).std()['problemid']
    counts_day_answer = group_by_day1.groupby(['itest_id']).count()['problemid']

    group_by_mon = dataframe.groupby(['itest_id','monthfinishquestion'])
    group_by_mon1 = group_by_mon.count()
    average_questions_by_mon = group_by_mon1.groupby(['itest_id']).mean()['problemid']
    std_questions_by_mon = group_by_mon1.groupby(['itest_id']).std()['problemid']
    counts_mon_answer = group_by_mon1.groupby(['itest_id']).count()['problemid']
    
    data = {'average_questions_by_day':average_questions_by_day,'std_questions_by_day':std_questions_by_day,
           'counts_day_answer':counts_day_answer,'average_questions_by_mon':average_questions_by_mon,
           'std_questions_by_mon':std_questions_by_mon,'counts_mon_answer':counts_mon_answer}
    new_frame = pd.DataFrame(data)
    
    return new_frame

# %%
# all
all_date = create_date_info_dataframe(stu_que_matrix)
c1_date = create_date_info_dataframe(df_class1)
c2_date = create_date_info_dataframe(df_class2)
c3_date = create_date_info_dataframe(df_class3)
# add up
student_info_matrix = student_info_matrix.join(all_date,how='outer')
student_info_matrix = student_info_matrix.join(c1_date.rename(columns = lambda x:x+'_M'),how='outer')
student_info_matrix = student_info_matrix.join(c2_date.rename(columns = lambda x:x+'_H'),how='outer')
student_info_matrix = student_info_matrix.join(c3_date.rename(columns = lambda x:x+'_E'),how='outer')

# %% [markdown]
# 第三类，仅与题目相关
#
# 比如，题目超过80秒但是还是答错的

# %%
def over80_but_fair(dataframe):
    dataframe['timetaken_over80'] = (dataframe['timetaken']>80).astype(int)
    dataframe['wrong_over80'] = ((dataframe['timetaken_over80'] > 0) & (dataframe['correctrate'] == 0)).astype(int)
    group1 = dataframe.groupby('itest_id')
    wrong_and_over80 = group1.sum()['wrong_over80'] / group1.count()['problemid']
    return wrong_and_over80

# %%
student_info_matrix['wrong_and_over80'] = over80_but_fair(stu_que_matrix)
student_info_matrix['wrong_and_over80_M'] = over80_but_fair(df_class1)
student_info_matrix['wrong_and_over80_H'] = over80_but_fair(df_class2)
student_info_matrix['wrong_and_over80_E'] = over80_but_fair(df_class3)
# Out:
# C:\Users\surface\Anaconda2\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\surface\Anaconda2\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
student_info_matrix.to_csv("student_information_106.csv")
